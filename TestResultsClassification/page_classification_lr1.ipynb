# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /Users/cpan/anaconda3/lib/python3.10/site-packages (4.24.0)
# Requirement already satisfied: numpy>=1.17 in /Users/cpan/anaconda3/lib/python3.10/site-packages (from transformers) (1.23.5)
# Requirement already satisfied: pyyaml>=5.1 in /Users/cpan/anaconda3/lib/python3.10/site-packages (from transformers) (6.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.10.0 in /Users/cpan/anaconda3/lib/python3.10/site-packages (from transformers) (0.10.1)
# Requirement already satisfied: regex!=2019.12.17 in /Users/cpan/anaconda3/lib/python3.10/site-packages (from transformers) (2022.7.9)
# Requirement already satisfied: packaging>=20.0 in /Users/cpan/anaconda3/lib/python3.10/site-packages (from transformers) (22.0)
# Requirement already satisfied: filelock in /Users/cpan/anaconda3/lib/python3.10/site-packages (from transformers) (3.9.0)
# Requirement already satisfied: requests in /Users/cpan/anaconda3/lib/python3.10/site-packages (from transformers) (2.28.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /Users/cpan/anaconda3/lib/python3.10/site-packages (from transformers) (0.11.4)
# Requirement already satisfied: tqdm>=4.27 in /Users/cpan/anaconda3/lib/python3.10/site-packages (from transformers) (4.64.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/cpan/anaconda3/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.10.0->transformers) (4.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/cpan/anaconda3/lib/python3.10/site-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/cpan/anaconda3/lib/python3.10/site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/cpan/anaconda3/lib/python3.10/site-packages (from requests->transformers) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in /Users/cpan/anaconda3/lib/python3.10/site-packages (from requests->transformers) (3.4)

# %%
import numpy as np
import pandas as pd
import torch
from transformers import BertTokenizer, BertModel
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegressionCV
from sklearn.model_selection import cross_val_score
from sklearn.metrics import f1_score
from imblearn.over_sampling import RandomOverSampler

# %%
input_dir = '/Users/cpan/OneDrive - Guardant Health/page_classification_data/'
train_data = pd.read_csv(input_dir + 'train_docs.csv')
valid_data = pd.read_csv(input_dir + 'valid_docs.csv')
test_data = pd.read_csv(input_dir + 'test_docs.csv')

# %%
train_data.head()
# Out:
#                         file_name patient_id  \
# 0          A0311306/image-022.txt   A0311306
# 1          A0329908/image-002.txt   A0329908
# 2          A0125350/image-000.txt   A0125350
# 3          A0311306/image-021.txt   A0311306
# 4  A0400913_MedRec1/image-007.txt   A0400913
#
#                                         page_content  label
# 0  orsinger, veronika (a0311306) guardant 36 dob:...      0
# 1  [**REDACTED**], [**REDACTED**] (40329908) guar...      0
# 2  10/29/2018 4:04 pm fax 2066861268 lifespring c...      0
# 3  orsinger, veronika (a0311306) dob: oct-12-1961...      0
# 4  vendice, [**REDACTED**] (a040091 3) guardant 3...      0

# %%
# Initialize the BERT tokenizer and model
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertModel.from_pretrained('bert-base-uncased')
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.weight', 'cls.predictions.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
# Function to extract BERT embeddings for text data
def extract_bert_features(df):
    embeddings = []
    for text in df['page_content']:
        inputs = tokenizer(text, padding=True, truncation=True, return_tensors="pt")
        with torch.no_grad():
            outputs = model(**inputs)
        last_hidden_states = outputs.last_hidden_state
        avg_pooling = torch.mean(last_hidden_states, dim=1)
        embeddings.append(avg_pooling.squeeze().numpy())
    return np.vstack(embeddings)

# Extract BERT features for train, validation, and test sets
train_features = extract_bert_features(train_data)
val_features = extract_bert_features(valid_data)
test_features = extract_bert_features(test_data)

# %%
X_train = train_features
y_train = train_data['label']
X_val = val_features
y_val = valid_data['label']

# %%
# Apply oversampling to the training set since imbalanced data distribution 
oversampler = RandomOverSampler(random_state=42)
X_train_resampled, y_train_resampled = oversampler.fit_resample(X_train, y_train)
# not apply resamplling to validation data --> cuz it will introduce bias to the model's generalization

# %%
# Initialize the logistic regression classifier with hyperparameter tuning (L1, L2, and elasticnet regularization)
log_reg_l1 = LogisticRegressionCV(Cs=10, cv=5, penalty='l1', solver='liblinear', max_iter=100, scoring='f1')
log_reg_l2 = LogisticRegressionCV(Cs=10, cv=5, penalty='l2', solver='liblinear', max_iter=100, scoring='f1')
log_reg_elasticnet = LogisticRegressionCV(Cs=10, cv=5, penalty='elasticnet', solver='saga', max_iter=100, l1_ratios=[0.5], scoring='f1')

# Perform 5-fold cross-validation with hyperparameter tuning on the combined train and validation data
cv_scores_l1 = cross_val_score(log_reg_l1, X_val, y_val, cv=5)
cv_scores_l2 = cross_val_score(log_reg_l2, X_val, y_val, cv=5)
cv_scores_elasticnet = cross_val_score(log_reg_elasticnet, X_val, y_val, cv=5)

# Print cross-validation scores and mean F1 score
print("Cross-Validation F1 Scores (L1):", cv_scores_l1)
print("Mean F1 Score (L1):", np.mean(cv_scores_l1))

print("Cross-Validation F1 Scores (L2):", cv_scores_l2)
print("Mean F1 Score (L2):", np.mean(cv_scores_l2))

print("Cross-Validation F1 Scores (ElasticNet):", cv_scores_elasticnet)
print("Mean F1 Score (ElasticNet):", np.mean(cv_scores_elasticnet))
# Out:
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Cross-Validation F1 Scores (L1): [0.5        0.75       0.33333333 0.66666667 0.66666667]
# Mean F1 Score (L1): 0.5833333333333333
# Cross-Validation F1 Scores (L2): [0.66666667 0.75       0.33333333 0.4        0.8       ]
# Mean F1 Score (L2): 0.5900000000000001
# Cross-Validation F1 Scores (ElasticNet): [0.4        0.66666667 0.4        0.4        0.5       ]
# Mean F1 Score (ElasticNet): 0.47333333333333333
# /Users/cpan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(

# %%
# Choose the best model based on cross-validation F1 scores
X_test = test_features
y_test = test_data['label']
best_model = log_reg_l1

# Train the best model on the combined training and validation data
best_model.fit(X_train_resampled, y_train_resampled)

# Evaluate the best model on the test set using extracted BERT features
y_pred = best_model.predict(X_test)

# Calculate F1 score on the test set
test_f1_score = f1_score(y_test, y_pred)
print("Test F1 Score:", test_f1_score)
# Out:
# Test F1 Score: 0.6190476190476191

# %%
predictions_df = pd.DataFrame({"file_name": test_data["file_name"], 'patient_id': test_data['patient_id'], 'page_content':test_data['page_content'],"predicted_test_name": y_pred})

# %%
predictions_df.head()
# Out:
#                         file_name patient_id  \
# 0          A0184575/image-024.txt   A0184575
# 1  A0285660_MedRec1/image-050.txt   A0285660
# 2  A0557898_MedRec1/image-003.txt   A0557898
# 3          A0266158/image-020.txt   A0266158
# 4  A0394647_medrec1/image-064.txt   A0394647
#
#                                         page_content  predicted_test_name
# 0  41/29/21 14:17:28 city of hope > 18772418243 c...                    0
# 1  [**REDACTED**], [**REDACTED**]a0285660) cuarda...                    0
# 2  [**REDACTED**] 109) 11/1/2022 12:00:06 pm cdt ...                    0
# 3  ucdhs-o1 3/7/2021 3:14:44 pm page 23/035 fax b...                    0
# 4  a more detailed guardant360 patient report is ...                    0

# %%
print(predictions_df.shape)
predictions_df['predicted_test_name'].value_counts()
# Out:
# (419, 4)
# 0    396
# 1     23
# Name: predicted_test_name, dtype: int64

# %%
from sklearn.metrics import precision_recall_fscore_support

# Assuming y_true contains the true labels and y_pred contains the predicted labels
precision, recall, f1_score, _ = precision_recall_fscore_support(y_test, y_pred, average='binary')

print("Precision:", precision)
print("Recall:", recall)
print("F1-Score:", f1_score)
# Out:
# Precision: 0.5652173913043478
# Recall: 0.6842105263157895
# F1-Score: 0.6190476190476191

# %%
predictions_df.to_csv(input_dir+'predicted_test_results1.csv', index=False)

# %% [markdown]
# ### Error Analysis

# %%
from sklearn.metrics import confusion_matrix

# Print confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)

# Find indices of misclassified examples
misclassified_indices = np.where(y_test != y_pred)[0]

# Print some of the misclassified examples for analysis
num_examples_to_print = 5
print("\nMisclassified Examples:")
for i in range(min(num_examples_to_print, len(misclassified_indices))):
    index = misclassified_indices[i]
    print(f"Example {i+1}:")
    print("True Label:", y_test.iloc[index])
    print("Predicted Label:", y_pred[index])
    print("Text:")
    print(test_data['page_content'].iloc[index])
    print("="*50)

# Analyze common words or phrases in misclassified examples
misclassified_text = test_data['page_content'].iloc[misclassified_indices]
common_words = {}
for text in misclassified_text:
    words = text.split()
    for word in words:
        if word not in common_words:
            common_words[word] = 1
        else:
            common_words[word] += 1

# Print most common words in misclassified examples
print("Common Words in Misclassified Examples:")
sorted_common_words = sorted(common_words.items(), key=lambda x: x[1], reverse=True)
for word, count in sorted_common_words[:10]:
    print(f"{word}: {count}")

# Additional analysis could involve checking if there are specific types of pages (e.g., medical, technical) that the model struggles with,
# and using this information to fine-tune features or the model itself.
# Out:
# Confusion Matrix:
# [[390  10]
#  [  6  13]]
#
# Misclassified Examples:
# Example 1:
# True Label: 0
# Predicted Label: 1
# Text:
# 2022/02/04 13:50:24 76 /110 physical exam general: patient appears: chronically ill. in no apparent distress. psychiatric: judgment and insight are normal. appropriate mood and affect. memory appears intact. eyes: lids without lesions, conjunctiva clear. positive for scleral icterus [**REDACTED**]. ears, nose, mouth & throat: masking in place for [**REDACTED**] neck: neck is symmetrical with no masses and midline trachea. cardiovascular: heart with regular rate and rhythm. no murmur present. lower extremity edema trace. respiratory: normal respiratory effort. clear, no rales/rhonchi. no wheezing. gastrointestional: abdomen tender. positive for [**REDACTED**]. abdomen firm. no [**REDACTED**]. no ascites. hematologic/lymphatic: no petechiae. ecchymosis present. skin: jaundiced appearing musculoskeletal: no joint swelling. no cyanosis. no clubbing. abnormal gait and station, in wheelchair today. positive for lower extremity edema, trace. neurologic: alert and oriented. non focal exam. laboratory results lab results on 9/14/2020: wbc=20.3 k/ul, lymph%=2.2 %, lymph#=0.5 k/ul, mono%=5.2 %, [**REDACTED**], neut%=90.2 %, neut#=18.3 k/ul, eos%=0.00 %, [**REDACTED**] k/ul, baso%=0.10 %, baso#=0.03 k/ul, ig%=2.30 %, ig#=0.46 10(3)/ul, rbc=3.80 m/ul, hgb=12.3 g/dl, hct=34.4 %, mcv=90.5 fl, mch=32.4 pg, mchc=35.8 g/dl, rdw=17.10 %, plt=306 k/ul, [**REDACTED**] fl imaging results assessment 9/3/2020: malignant neoplasm of vagina - ajcc v8 clinical stage ivb assessment and plan 1. metastatic squamous cell carcinoma of vagina, with extensive liver metastatic disease, and jaundice from diffuse involvement of liver: at this time we discussed with her that the guardant360 did come back showing that msi-high was negative and her only mutation was a pik3ca [**REDACTED**] which did not show any compatible treatments for her disease type. the pd-l1 testing did come back as well showing no expression. we had a very long discussion with her and her husband about the fact that she would not be a very good candidate for chemotherapy given her current liver function and a bilirubin that is over 20. she could however try with cisplatin again, but with her having this before with unimpressive results, this may not yield any better outcome. at this time she would not get any benefit from immunctherapy given her low pd-l1 status and does not have any targetable mutations so far. we are still awaiting the foundation one testing at this time. her husband did mention about trying an alternative therapy in south dakota which is a satellite office fram the [**REDACTED**] that is conducting trials on patients. we discussed with them that they should try this if that is what they want otherwise hospice may be the next best option for her. given her increasing symptoms we will go ahead and set her up to see palliative and we will see her back in 2 weeks. at that time her foundation testing should be back. she is agreeable with this plan. 2.constipation: we will start her on lactulose at this time. 3.sleep: will try her on trazodone 50 to 100 mg at bedtime ta see if this will help. interventions notified of pain level by clinical support team. distress interventions: apn visit patient was seen in conjunction with dr. [**REDACTED**], who also examined the patient and formulated the plan. the comorbidities listed above were considered in the decision making process. fax recipients: [**REDACTED**], [**REDACTED**];
# ==================================================
# Example 2:
# True Label: 1
# Predicted Label: 0
# Text:
# [**REDACTED**], 6 2018 1:25pm no. 2926 =p. 11/37 page 2 of 8 05/16/2018 [**REDACTED**] md re:[**REDACTED**] joines, dob: [**REDACTED**] panel germline testing with myriad myrisk was negative. in july 2014, her-2 fish showed a ratio of 1.2 with her-2 signals per cell of 2.7. the markers including her-2 were not repeated on the mastectomy. in april 2015, she started treatment with zoladex, letrozole, and ibrance. she did have sr& radiation to her lung metastasis
ation sequencing with guardant360 peripheral blood interval histo : since | last saw the patient she is noticing increasing bloating and early satiety. no real abdominal pain. she feels she is open pregnant”. no weight loss though. no vomiting. ct scans were done showing new development of ascites and suggestion of peritoneal carcinomatosis. she is brought in today to discuss this further husband is accompanying her. she still taking the palbociclib and is not due for her next shot fulvestrant until next week. she is noticing increasing diarrhea 3-4 times a day now. and is needing imodium was daily. reviewofs stem: diarrhea 3-4 times a day need imodium daily abdominal bloating and early satiety minor nausea. no real weight loss that is evident to her but for our records with weight july 1, 2021 = 194 ib baseline 197 ib minor neuropathy in the fingertips and toes which termittant grade 1 since she received taxol in 2009. not affecting functioning. no history of new lumps, fevers, night sweats or unintentional weight loss no new pain or new concerning issues raised [**REDACTED**] done and is negative except as above. nerated by 13 oat : m page 46
# ==================================================
# Example 5:
# True Label: 0
# Predicted Label: 1
# Text:
# 09/02/2022 2:31:26 pm —-0500 faxcom page 22 of 28 fat [**REDACTED**] y ’ @center for advanced medicinepecha, dianne b a as 4921 parkview pi mrn: 108639778, dob: 10/7/1966, sex: f soe [**REDACTED**] mo 63110-1032 visit date: 2/7/2022 university inst.louis “’""""p" physicians eosinophil pct 0.9 % basophil pct 2.1 % egfr collection time: 02/07/22 9:09 am result value [**REDACTED**] range egfr 87 (l) 90 - 130 ml/min/1.73 [**REDACTED**] and plan: 1. breast cancer now with bone mets: in sum[**REDACTED**]ry, dianne b pecha is a 55 y.o. fe[**REDACTED**]le with bone mets diagnosed in [**REDACTED**]y 2021. her ca15.3 is slightly more elevated today, 49.1. will recheck guardant360 response. plan to restage in 2 months. we agreed to continue the same regimen at this time but monitor closely. we also reviewed potential options for future treatments, including pi3k inhibitor for pik3ca mutated breast cancer, and participation in nci protocol 10287 which combines fulvestrant with abe[**REDACTED**]cilcib and the pi3k inhibitor copanlisib if slots available. 2. bone mets: received first dose of zometa on 7/6/2021. continue zometa monthly the first year. 3. left axillar skin nodules: atypical vascular proliferation. however since she has had prior radiation, saw by sarco[**REDACTED**] specialist [**REDACTED**], not [**REDACTED**]. will follow up with [**REDACTED**] tine in [**REDACTED**] [**REDACTED**], [**REDACTED**], [**REDACTED**] encounter messages appoiniment reminder from to sent and delivered mychart, generic dianne b pecha 1/31/2022 6:20 am last read in mychart not read department: [**REDACTED**] oncology 4921 parkview place center for advanced medicine 7th floor suite b [**REDACTED**], mo 63110-1032 314-747-1171 provider: [**REDACTED**], [**REDACTED**], [**REDACTED**] [**REDACTED**] generated by m96580 at 5/2/22 2:26 pm page 21
# ==================================================
# Common Words in Misclassified Examples:
# and: 119
# [**REDACTED**]: 107
# the: 107
# of: 103
# in: 90
# no: 90
# with: 82
# to: 68
# [**REDACTED**],: 61
# is: 57

# %%
print(len(misclassified_indices))
# Out:
# 16

# %%
import re

# Initialize a counter for occurrences of "guardant" or its part
guardant_count = 0

# Analyze common words or phrases in misclassified examples
misclassified_text = test_data['page_content'].iloc[misclassified_indices]

for text in misclassified_text:
    if re.findall(r'\bguardant\b', text):  # Using \b to match whole word "guardant"
        guardant_count += 1

# Print the number of misclassified examples containing "guardant" or its part
print("Number of Misclassified Examples Containing 'guardant':", guardant_count)
# Out:
# Number of Misclassified Examples Containing 'guardant': 0
